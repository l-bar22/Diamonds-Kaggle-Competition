# %% [markdown]
# # DIAMONDS - KAGGLE COMPETITION

# %%
#Importar módulos para trabajar
import pandas as pd
import numpy as np
import researchpy as rp
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
#Usando el módulo pandas la función read_csv permite leer el archivo csv usando la ruta dónde se encuentra ubicado.
diamonds=pd.read_csv('./INPUT/train.csv' )
diamonds.head(11)
# Out:
#     id  carat        cut color clarity  depth  table     x     y     z  price
# 0    0   0.30  Very Good     F     VS2   62.8   56.0  4.29  4.31  2.70    605
# 1    1   0.34      Ideal     E     SI1   62.6   55.0  4.46  4.49  2.80    565
# 2    2   0.40  Very Good     D     SI1   60.3   62.0  4.70  4.75  2.85    720
# 3    3   0.40    Premium     H     VS1   61.8   59.2  4.72  4.74  2.92    793
# 4    4   0.90  Very Good     D     SI1   61.0   63.0  6.10  6.13  3.73   4381
# 5    5   0.60      Ideal     D     SI1   61.7   56.0  5.39  5.44  3.34   2263
# 6    6   0.32       Good     E     SI1   63.1   54.0  4.37  4.41  2.77    524
# 7    7   0.30    Premium     E     VS2   60.0   60.0  4.40  4.36  2.63    844
# 8    8   0.52    Premium     G     VS2   62.4   56.0  5.19  5.16  3.23   1577
# 9    9   0.41  Very Good     E     SI1   61.8   60.0  4.74  4.78  2.94    705
# 10  10   0.31      Ideal     G     SI2   61.6   55.6  4.34  4.37  2.69    429

# %%
diamonds.shape
# Out:
# (40455, 11)

# %%
'''Usando la función info se obtienen,cuántas columnas hay que información proporcionan,cuántos datos hay en cada columna,
el tipo de datos,y si existen valores nulos o no. '''

diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       40455 non-null  int64
#  1   carat    40455 non-null  float64
#  2   cut      40455 non-null  object
#  3   color    40455 non-null  object
#  4   clarity  40455 non-null  object
#  5   depth    40455 non-null  float64
#  6   table    40455 non-null  float64
#  7   x        40455 non-null  float64
#  8   y        40455 non-null  float64
#  9   z        40455 non-null  float64
#  10  price    40455 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 3.4+ MB

# %%
#Se comprueba además si existen valores duplicados.
diamonds.duplicated().sum()
# Out:
# 0

# %%
#Existen dos tipos de datos en el dataframe,8 de tipo cuantitativo y 3 de tipo categórico.
#Se debe hacer una observación para saber si los datos categóricos están repetidos o no.
diamonds['color'].unique()
# Out:
# array([2, 1, 0, 4, 3, 6, 5])

# %%
#Tablas de frecuencia
diamonds['cut'].value_counts().plot(kind='bar',title='Cut frequency')

# %%
diamonds['color'].value_counts().plot(kind='bar',title='Color frequency')

# %%
diamonds['clarity'].value_counts().plot(kind='bar',title='Clarity frequency')

# %%
#label encoding para poder transformar datos categóricos en datos cuantitativos.
from sklearn import preprocessing
cat_columns=['cut','color','clarity']
for column in cat_columns:
    label_encoder=preprocessing.LabelEncoder()
    label_encoder.fit(diamonds[column])
    diamonds[column]=label_encoder.transform(diamonds[column])
diamonds.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   0.30    4      2        5   62.8   56.0  4.29  4.31  2.70    605
# 1   1   0.34    2      1        2   62.6   55.0  4.46  4.49  2.80    565
# 2   2   0.40    4      0        2   60.3   62.0  4.70  4.75  2.85    720
# 3   3   0.40    3      4        4   61.8   59.2  4.72  4.74  2.92    793
# 4   4   0.90    4      0        2   61.0   63.0  6.10  6.13  3.73   4381

# %%
#¿Qué relación existe entre las diferentes columnas?
diamonds.corr()
# Out:
#                id     carat       cut     color   clarity     depth     table  \
# id       1.000000  0.002653  0.001979 -0.007942  0.002959  0.002349 -0.006281
# carat    0.002653  1.000000  0.020662  0.289150 -0.212821  0.032379  0.181791
# cut      0.001979  0.020662  1.000000  0.002828  0.025718 -0.188766  0.149559
# color   -0.007942  0.289150  0.002828  1.000000 -0.025578  0.046420  0.026387
# clarity  0.002959 -0.212821  0.025718 -0.025578  1.000000 -0.054104 -0.084703
# depth    0.002349  0.032379 -0.188766  0.046420 -0.054104  1.000000 -0.297164
# table   -0.006281  0.181791  0.149559  0.026387 -0.084703 -0.297164  1.000000
# x        0.001529  0.974898  0.025532  0.267955 -0.224169 -0.020876  0.194763
# y        0.001976  0.944513  0.030438  0.259464 -0.214578 -0.025105  0.181585
# z        0.004030  0.947538  0.005945  0.263969 -0.221445  0.099375  0.149242
# price    0.006826  0.922567  0.040733  0.171269 -0.072106 -0.005105  0.129777
#
#                 x         y         z     price
# id       0.001529  0.001976  0.004030  0.006826
# carat    0.974898  0.944513  0.947538  0.922567
# cut      0.025532  0.030438  0.005945  0.040733
# color    0.267955  0.259464  0.263969  0.171269
# clarity -0.224169 -0.214578 -0.221445 -0.072106
# depth   -0.020876 -0.025105  0.099375 -0.005105
# table    0.194763  0.181585  0.149242  0.129777
# x        1.000000  0.967114  0.965114  0.884089
# y        0.967114  1.000000  0.940678  0.858536
# z        0.965114  0.940678  1.000000  0.855923
# price    0.884089  0.858536  0.855923  1.000000

# %%
rp.summary_cont(diamonds[['cut', 'carat','color','clarity']])
# Out:
#   Variable        N      Mean        SD        SE  95% Conf.  Interval
# 0      cut  40455.0  2.556569  1.027918  0.005111   2.546552  2.566586
# 1    carat  40455.0  0.797150  0.472872  0.002351   0.792542  0.801758
# 2    color  40455.0  2.598294  1.698944  0.008447   2.581738  2.614850
# 3  clarity  40455.0  3.839748  1.722592  0.008564   3.822961  3.856534

# %%
diamonds.drop(columns=["depth","x","z",'y','table']).head(11)
# Out:
#     id  carat  cut  color  clarity  price
# 0    0   0.30    4      2        5    605
# 1    1   0.34    2      1        2    565
# 2    2   0.40    4      0        2    720
# 3    3   0.40    3      4        4    793
# 4    4   0.90    4      0        2   4381
# 5    5   0.60    2      0        2   2263
# 6    6   0.32    1      1        2    524
# 7    7   0.30    3      1        5    844
# 8    8   0.52    3      3        5   1577
# 9    9   0.41    4      1        2    705
# 10  10   0.31    2      3        3    429

# %%
import seaborn as sns

sns.heatmap(diamonds.corr(),annot=True)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.experimental import enable_hist_gradient_boosting 
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
from sklearn.model_selection import train_test_split
y = diamonds["price"]
X = diamonds[["carat", "cut", "color", "clarity",]]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
models = {
    "forest": RandomForestRegressor(n_estimators=250),
    "GBR": HistGradientBoostingRegressor(),
    "GBR2": GradientBoostingRegressor()
}

for modelName, model in models.items():
    print(f"Training model: {modelName}")
    model.fit(X_train, y_train)
    print(f"Training finished: {modelName}")
# Out:
# Training model: forest
# Training finished: forest
# Training model: GBR
# Training finished: GBR
# Training model: GBR2
# Training finished: GBR2

# %%
d = {modelName:model.predict(X_test) for modelName, model in models.items()}

df = pd.DataFrame(d)
df["gt"] = y_test.reset_index(drop=True)
df.head()
# Out:
#         forest          GBR         GBR2    gt
# 0  7806.354840  7560.735282  6643.762667  8333
# 1  3910.002764  3757.114636  3729.248324  4712
# 2  2542.997681  2555.522516  2675.045942  2673
# 3  1728.301438  1716.559705  1751.236861  1721
# 4  5447.813381  5520.841945  5314.160333  5293

# %%
kf = KFold(n_splits=2, shuffle=True, random_state=11)
for k, v in models.items():
    scores = cross_val_score(v, X_train, y_train, scoring='r2', cv=kf, n_jobs=2)
    name = str(v)
    print(f'{name}: Average R-Squared Score:', np.mean(scores))
# Out:
# RandomForestRegressor(n_estimators=250): Average R-Squared Score: 0.9763401161513333
# HistGradientBoostingRegressor(): Average R-Squared Score: 0.9795798637071169
# GradientBoostingRegressor(): Average R-Squared Score: 0.9715327940231968

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmseGBR = sqrt(mean_squared_error(y_test, d['GBR']))
rmseGBR2 = sqrt(mean_squared_error(y_test, d['GBR2']))
rmseForest = sqrt(mean_squared_error(y_test, d['forest']))
print(f"forest: {rmseForest}, GBR: {rmseGBR}, GBR2: {rmseGBR2}")
# Out:
# forest: 588.7863873857133, GBR: 556.1743696642528, GBR2: 658.2676080066781

# %%
test_diamonds = pd.read_csv('./INPUT/predict.csv')

# %%
test_diamonds.head()
# Out:
#    id  carat    cut color clarity  depth  table     x     y     z
# 0   0   2.36  Ideal     I     SI2   60.8   54.0  8.68  8.57  5.24
# 1   1   2.04  Ideal     H     SI2   62.0   56.0  8.18  8.23  5.09
# 2   2   0.51  Ideal     I     SI1   61.7   54.0  5.18  5.19  3.20
# 3   3   0.30  Ideal     I     SI1   61.3   56.0  4.32  4.33  2.65
# 4   4   0.96   Fair     H     VS2   68.8   56.0  6.11  5.98  4.16

# %%
cat_columns=['cut','color','clarity']
for column in cat_columns:
    label_encoder=preprocessing.LabelEncoder()
    label_encoder.fit(test_diamonds[column])
    test_diamonds[column]=label_encoder.transform(test_diamonds[column])
test_diamonds.head()
# Out:
#    id  carat  cut  color  clarity     depth     table         x         y  \
# 0   0   2.36    2      5        3 -0.666318 -1.554540  2.620734  2.539800
# 1   1   2.04    2      4        3  0.168508 -0.658049  2.175567  2.234832
# 2   2   0.51    2      5        2 -0.040199 -1.554540 -0.495431 -0.491942
# 3   3   0.30    2      5        2 -0.318474 -0.658049 -1.261117 -1.263332
# 4   4   0.96    0      4        5  4.899190 -0.658049  0.332578  0.216660
#
#           z
# 0  2.446736
# 1  2.230593
# 2 -0.492811
# 3 -1.285335
# 4  0.890505

# %%
columns = ['depth', 'table', 'x', 'y', 'z']
for col in columns:
    test_diamonds[col] = (test_diamond[col] - np.mean(test_diamond[col])) / np.std(test_diamond[col]) 

test_diamonds.head()
# Out:
#    id  carat  cut  color  clarity     depth     table         x         y  \
# 0   0   2.36    2      5        3 -0.666318 -1.554540  2.620734  2.539800
# 1   1   2.04    2      4        3  0.168508 -0.658049  2.175567  2.234832
# 2   2   0.51    2      5        2 -0.040199 -1.554540 -0.495431 -0.491942
# 3   3   0.30    2      5        2 -0.318474 -0.658049 -1.261117 -1.263332
# 4   4   0.96    0      4        5  4.899190 -0.658049  0.332578  0.216660
#
#           z
# 0  2.446736
# 1  2.230593
# 2 -0.492811
# 3 -1.285335
# 4  0.890505

# %%
d1 = {modelName:model.predict(test_diamonds[["carat", "cut", "color", "clarity"]]) for modelName, model in models.items()}

df1 = pd.DataFrame(d1)
df1['id']=test_diamonds['id']
diamonds_new = df1[['id','forest']]
diamonds_new.rename(columns={"forest": "price"}, inplace=True)
diamonds_new.head()
# Out:
# /home/laura/.local/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    id         price
# 0   0  16670.450067
# 1   1  16391.174067
# 2   2   1024.081711
# 3   3    442.421375
# 4   4   3905.253637

# %%
diamonds_new.head()
# Out:
#            price
# id
# 0   16670.450067
# 1   16391.174067
# 2    1024.081711
# 3     442.421375
# 4    3905.253637

# %%
diamonds_new.to_csv('./OUTPUT/diamonds1.csv' )
